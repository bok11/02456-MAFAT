# %% [markdown]
# # Nerual Network for Classifying fine-grained images

# %%
import torch
import torch.nn as nn
import torchvision
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
train = pd.read_csv("./data/dataset_v2/train.csv")

# %%
train.head(10)
# Out:
#    tag_id  image_id         p1_x         p_1y         p2_x         p2_y  \
# 0   15036     16490  3988.399902  1227.588745  3986.710693  1213.288208
# 1   31658     16490  3380.804152    33.370945  3329.811654   128.465062
# 2   26971     17122  3948.334473  1426.797241  3958.876221  1410.750122
# 3   19301     12193  1977.798007  1009.010733  1983.435998   992.096760
# 4   35906     12193  3196.620177  1284.240545  3193.174738  1311.804057
# 5   33775     12193  3467.501709    22.044827  3464.846924     0.608574
# 6   24690     19725  2456.478109  2010.104212  2441.469776  2035.118099
# 7   27442     19531   737.060547  1103.635864   753.927307  1117.129272
# 8   26689     19531  2306.666955   202.390016  2292.688464   225.687500
# 9   38403     13124   598.145269   598.300277   614.452473   588.856595
#
#           p3_x         p3_y         p4_x         p4_y     ...       \
# 0  4002.600098  1211.411255  4004.289307  1225.711792     ...
# ...
